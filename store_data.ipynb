# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import pandas as pd

# %%
import pymongo as pym
pym.__version__
# Out:
# '4.5.0'

# %%
password = "hoangthinhnguyen"
uri = "mongodb+srv://hoangthinhnguyen:{}@cluster0.1wsiirv.mongodb.net/?retryWrites=true&w=majority".format(password)

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# ('ac-mymzyb2-shard-00-02.1wsiirv.mongodb.net', 27017)

# %%
print(client.arbiters)
# Out:
# set()

# %%
db = client['Task2_Database']
collection = db['shopee_data']

# %%
# Get data from MongoDB
data = list(collection.find())

# Read data from MongoDB and save it in a list
cursor = collection.find()
data_list = []
for document in cursor: 
    del document['_id']
    data_list.append(document)


df = pd.DataFrame(data_list)

# Save dataframe to CSV
df.to_csv('file.csv',index=False,header=True,encoding="utf-8-sig")

# %%
df
# Out:
#                crawl_time     mall_id        mall_name  \
# 0     2023-10-29 22:57:27     sp.btw2  Aviano Menswear
# 1     2023-10-29 22:57:39     sp.btw2  Aviano Menswear
# 2     2023-10-29 22:58:02     sp.btw2  Aviano Menswear
# 3     2023-10-29 22:58:11     sp.btw2  Aviano Menswear
# 4     2023-10-29 22:58:21     sp.btw2  Aviano Menswear
# ...                   ...         ...              ...
# 1533  2023-10-30 19:19:52  levents.vn      Levents .vn
# 1534  2023-10-30 19:20:00  levents.vn      Levents .vn
# 1535  2023-10-30 19:20:09  levents.vn      Levents .vn
# 1536  2023-10-30 19:20:18  levents.vn      Levents .vn
# 1537  2023-10-30 19:20:28  levents.vn      Levents .vn
#
#                                                  titles  \
# 0     Áo Giữ Nhiệt Nam Dài Tay AVIANO Vải Heattech C...
# 1     [Mã FATREND2810 giảm đến 30k tối đa 99k] Áo Kh...
# 2     [Mã FATREND2810 giảm đến 30k tối đa 99k] Áo Kh...
# 3     Áo Khoác Nam AVIANO Có Mũ Tháo Rời, Áo Khoác G...
# ...
